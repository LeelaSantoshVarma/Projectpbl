# %%
# Student Details Program

name = input("Enter Student Name: ")
roll_no = input("Enter Roll Number: ")
course = input("Enter Course: ")

print("\n----- Student Details -----")
print("Name      :", name)
print("Roll No   :", roll_no)
print("Course    :", course)
# Out:
# Enter Student Name:  vijaya Lakshmi
# Enter Roll Number:  908193
# Enter Course:  agriculture
# ----- Student Details -----
# Name      : vijaya Lakshmi
# Roll No   : 908193
# Course    : agriculture
