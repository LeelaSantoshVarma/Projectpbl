# %%
name = input("Enter Customer Name: ")
premium = input("Premium Member (yes/no): ")
amount = float(input("Purchase Amount: "))

if premium.lower() == "yes" and amount >= 1000:
    print("Discount Applied")
else:
    print("No Discount")
# Out:
# Enter Customer Name:  Lakshmi
# Premium Member (yes/no):  yes
# Purchase Amount:  1500
# Discount Applied
